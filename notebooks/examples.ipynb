# %%
Read("../cyclefree-permutation-generator.g");

# %% [markdown]
# # Example with n = 17 points

# %% [markdown]
# ## Initialise. This may take a bit longer for very large n.

# %%
n := 17;;
gen := InitCyclefreePermutationGenerator(n);;
time; # Prints the time in msec gap needed for this cell.
# Out:
# 1

# %% [markdown]
# ## Create one cyclefree permutation

# %%
GenerateCyclefreePermutation(gen);
# Out:
# (1,3,9,16,11,17,4,6,13,8,5,14,12,2,15,7,10)

# %% [markdown]
# ## Create a list of five cyclefree permutations

# %%
GenerateCyclefreePermutation(gen, 5);
# Out:
# [ (1,9,11,4,13,5,12,15,10,3,16,17,6,8,14,2,7), (1,16,4,8,12,7,3,11,6,5,2,10,9,17,13,14,15), (1,11,13,12,10,16,6,14,7,9,4,5,15,3,17,8,2), (1,17,5,7,16,13,2,3,4,14,10,11,8,15,9,6,12), (1,4,12,3,6,2,9,13,15,16,8,7,11,5,10,17,14) ]

# %% [markdown]
# # Try it yourselves!

# %%
n := 100007;;
gen := InitCyclefreePermutationGenerator(n);;
time; # Prints the time in msec gap needed for this cell.
# Out:
# 0

# %%
GenerateCyclefreePermutation(gen);
time;
# Out:
# (1,96618,94847,94346,96704,98082,94852,93304,94243,96839,95418,92798,96948,94443,94394,96328,93542,99780,94309,94292,94162,97443,93622,94464,93203,95448,440,94576,93222,96639,95477,97781,92467,95826,99564,95657,95456,97428,96482,92345,95414,93763,97988,96354,98250,97709,95131,95741,98141,98357,94732,94509,96299,94051,95696,94631,92008,97601,94962,97558,94029,93686,96203,96043,95011,95631,96431,96786,95681,95708,92206,95363,93913,98637,99103,96947,96794,95976,95054,94784,97592,93473,96396,92935,93497,94411,98090,96488,96669,58,94866,93517,97505,95428,96873,99659,94333,96453,94325,95787,94653,98689,92823,98138,94939,94679,95276,96407,96808,19,98044,96609,95433,95892,97899,93289,93695,98723,95083,97518,91353,93968,94940,93883,90840,91690,93724,90437,97300,95467,94558,95998,94757,97213,97077,97242,93899,95840,94626,93560,96141,97673,98488,93810,94078,94094,95974,97406,97439,97651,95288,96763,95688,98179,98021,96949,98224,95529,94956,96276,97022,94543,96886,94892,1368,94610,92653,95732,95
# ...
